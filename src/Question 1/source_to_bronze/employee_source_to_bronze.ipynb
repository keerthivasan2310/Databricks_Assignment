# %%
# %run ./utils

# %%
employee_df = spark.read.option("header", True).csv("/Volumes/workspace/default/assignment/input/Employee-Q1.csv")
department_df = spark.read.option("header", True).csv("/Volumes/workspace/default/assignment/input/Department-Q1.csv")
country_df = spark.read.option("header", True).csv("/Volumes/workspace/default/assignment/input/Country-Q1.csv")

# %%
employee_df.write.mode("overwrite").csv("/Volumes/workspace/default/assignment/source_bronze/employee")
department_df.write.mode("overwrite").csv("/Volumes/workspace/default/assignment/source_bronze/department")
country_df.write.mode("overwrite").csv("/Volumes/workspace/default/assignment/source_bronze/country")
